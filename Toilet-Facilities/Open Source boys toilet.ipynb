# %% [markdown]
# # Objective: An EDA (Exploratory Data Analysis) to analyse whether there are enough boys toilet facilities in Inidia Schools.

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#load data for analysis
df=pd.read_csv("schools-with-boys-toilet-2013-2016.csv")
df
# Out:
#                       State_UT     year  Primary_Only  Primary_with_U_Primary  \
# 0    Andaman & Nicobar Islands  2013-14         91.58                   97.37
# 1    Andaman & Nicobar Islands  2014-15        100.00                  100.00
# 2    Andaman & Nicobar Islands  2015-16        100.00                  100.00
# 3               Andhra Pradesh  2013-14         53.03                   62.58
# 4               Andhra Pradesh  2014-15         57.91                   76.51
# ..                         ...      ...           ...                     ...
# 105                West Bengal  2014-15         89.45                   80.43
# 106                West Bengal  2015-16         97.53                   92.44
# 107                  All India  2013-14         84.01                   91.44
# 108                  All India  2014-15         85.66                   93.93
# 109                  All India  2015-16         96.45                   98.40
#
# ...

# %%
#Get the  first five rows of the dataframe
df.head()
# Out:
#                     State_UT     year  Primary_Only  Primary_with_U_Primary  \
# 0  Andaman & Nicobar Islands  2013-14         91.58                   97.37
# 1  Andaman & Nicobar Islands  2014-15        100.00                  100.00
# 2  Andaman & Nicobar Islands  2015-16        100.00                  100.00
# 3             Andhra Pradesh  2013-14         53.03                   62.58
# 4             Andhra Pradesh  2014-15         57.91                   76.51
#
#    Primary_with_U_Primary_Sec_HrSec  U_Primary_Only  U_Primary_With_Sec_HrSec  \
# 0                            100.00            0.00                    100.00
# 1                            100.00          100.00                    100.00
# 2                            100.00            0.00                    100.00
# 3                             82.05           45.45                     64.11
# 4                             96.00           75.00                     93.33
#
# ...

# %%
#Get the data types of your dataframe values
df.dtypes
# Out:
# State_UT                             object
# year                                 object
# Primary_Only                        float64
# Primary_with_U_Primary              float64
# Primary_with_U_Primary_Sec_HrSec    float64
# U_Primary_Only                      float64
# U_Primary_With_Sec_HrSec            float64
# Primary_with_U_Primary_Sec          float64
# U_Primary_With_Sec                  float64
# Sec_Only                            float64
# Sec_with_HrSec.                     float64
# HrSec_Only                          float64
# All Schools                         float64
# dtype: object

# %%
#Get the number of rows and columns in the dataframe
df.shape
# Out:
# (110, 13)

# %%
#Get summary statistics of your data
df.describe()
# Out:
#        Primary_Only  Primary_with_U_Primary  Primary_with_U_Primary_Sec_HrSec  \
# count    110.000000              110.000000                        110.000000
# mean      90.433636               94.101727                         95.777182
# std       13.312718                9.393651                         13.991093
# min       38.240000               61.170000                          0.000000
# 25%       86.567500               93.525000                         97.932500
# 50%       96.045000               98.485000                         99.620000
# 75%       99.595000               99.857500                        100.000000
# max      100.000000              100.000000                        100.000000
#
#        U_Primary_Only  U_Primary_With_Sec_HrSec  Primary_with_U_Primary_Sec  \
# count      110.000000                110.000000                  110.000000
# mean        82.290182                 94.125636                   90.543364
# ...

# %%
#Check null values in the dataframe
df.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# State_UT                            0
# year                                0
# Primary_Only                        0
# Primary_with_U_Primary              0
# Primary_with_U_Primary_Sec_HrSec    0
# U_Primary_Only                      0
# U_Primary_With_Sec_HrSec            0
# Primary_with_U_Primary_Sec          0
# U_Primary_With_Sec                  0
# Sec_Only                            0
# Sec_with_HrSec.                     0
# HrSec_Only                          0
# All Schools                         0
# dtype: int64

# %%
# Get the list of categorical columns
df.select_dtypes(exclude=['int', 'float']).columns
# Out:
# Index(['State_UT', 'year'], dtype='object')

# %%
# Get the list of numerical columns
df.select_dtypes(include=['int', 'float']).columns
# Out:
# Index(['Primary_Only', 'Primary_with_U_Primary',
#        'Primary_with_U_Primary_Sec_HrSec', 'U_Primary_Only',
#        'U_Primary_With_Sec_HrSec', 'Primary_with_U_Primary_Sec',
#        'U_Primary_With_Sec', 'Sec_Only', 'Sec_with_HrSec.', 'HrSec_Only',
#        'All Schools'],
#       dtype='object')

# %%
#Check the correlation between the columns of the dataframe
df.corr()
# Out:
#                                   Primary_Only  Primary_with_U_Primary  \
# Primary_Only                          1.000000                0.895771
# Primary_with_U_Primary                0.895771                1.000000
# Primary_with_U_Primary_Sec_HrSec      0.114139                0.241072
# U_Primary_Only                        0.280768                0.256777
# U_Primary_With_Sec_HrSec              0.302537                0.336262
# Primary_with_U_Primary_Sec            0.126119                0.159843
# U_Primary_With_Sec                   -0.006617               -0.008146
# Sec_Only                              0.086444                0.113203
# Sec_with_HrSec.                       0.225765                0.238211
# HrSec_Only                            0.171621                0.154346
# All Schools                           0.986743                0.931423
#
#                                   Primary_with_U_Primary_Sec_HrSec  \
# ...

# %%
#Get information about the dataframe like index type,column type,non null values etc
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 13 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   State_UT                          110 non-null    object
#  1   year                              110 non-null    object
#  2   Primary_Only                      110 non-null    float64
#  3   Primary_with_U_Primary            110 non-null    float64
#  4   Primary_with_U_Primary_Sec_HrSec  110 non-null    float64
#  5   U_Primary_Only                    110 non-null    float64
#  6   U_Primary_With_Sec_HrSec          110 non-null    float64
#  7   Primary_with_U_Primary_Sec        110 non-null    float64
#  8   U_Primary_With_Sec                110 non-null    float64
#  9   Sec_Only                          110 non-null    float64
#  10  Sec_with_HrSec.                   110 non-null    float64
# ...

# %%
#Check if non-null values are in the dataframe
df.isnull()
# Out:
#      State_UT   year  Primary_Only  Primary_with_U_Primary  \
# 0       False  False         False                   False
# 1       False  False         False                   False
# 2       False  False         False                   False
# 3       False  False         False                   False
# 4       False  False         False                   False
# ..        ...    ...           ...                     ...
# 105     False  False         False                   False
# 106     False  False         False                   False
# 107     False  False         False                   False
# 108     False  False         False                   False
# 109     False  False         False                   False
#
#      Primary_with_U_Primary_Sec_HrSec  U_Primary_Only  \
# 0                               False           False
# 1                               False           False
# 2                               False           False
# ...

# %%
#Get the number of unique items in the dataframe
df.nunique(axis=0)
# Out:
# State_UT                            37
# year                                 3
# Primary_Only                        89
# Primary_with_U_Primary              84
# Primary_with_U_Primary_Sec_HrSec    64
# U_Primary_Only                      70
# U_Primary_With_Sec_HrSec            59
# Primary_with_U_Primary_Sec          68
# U_Primary_With_Sec                  68
# Sec_Only                            41
# Sec_with_HrSec.                     41
# HrSec_Only                          30
# All Schools                         91
# dtype: int64

# %%
#Check duplicated values of the dataframe
df.duplicated().value_counts()
# Out:
# False    110
# dtype: int64

# %%
#Get the columns of the dataframe
df.columns
# Out:
# Index(['State_UT', 'year', 'Primary_Only', 'Primary_with_U_Primary',
#        'Primary_with_U_Primary_Sec_HrSec', 'U_Primary_Only',
#        'U_Primary_With_Sec_HrSec', 'Primary_with_U_Primary_Sec',
#        'U_Primary_With_Sec', 'Sec_Only', 'Sec_with_HrSec.', 'HrSec_Only',
#        'All Schools'],
#       dtype='object')

# %%
#Get a part of the dataframe for analysis
dt=df.iloc[:,[0,1,2,5,9,11]]
dt
# Out:
#                       State_UT     year  Primary_Only  U_Primary_Only  \
# 0    Andaman & Nicobar Islands  2013-14         91.58            0.00
# 1    Andaman & Nicobar Islands  2014-15        100.00          100.00
# 2    Andaman & Nicobar Islands  2015-16        100.00            0.00
# 3               Andhra Pradesh  2013-14         53.03           45.45
# 4               Andhra Pradesh  2014-15         57.91           75.00
# ..                         ...      ...           ...             ...
# 105                West Bengal  2014-15         89.45           87.89
# 106                West Bengal  2015-16         97.53           98.86
# 107                  All India  2013-14         84.01           88.14
# 108                  All India  2014-15         85.66           88.12
# 109                  All India  2015-16         96.45           96.00
#
#      Sec_Only  HrSec_Only
# 0        0.00        0.00
# 1        0.00        0.00
# 2        0.00        0.00
# ...

# %% [markdown]
# # Since we want to analyse boys toilet facilties in schools of India,we get that information from the  data using the code below.

# %%
dg=dt.loc[df['State_UT'] == 'All India']
dg
# Out:
#       State_UT     year  Primary_Only  U_Primary_Only  Sec_Only  HrSec_Only
# 107  All India  2013-14         84.01           88.14     97.97       74.36
# 108  All India  2014-15         85.66           88.12     89.10       88.97
# 109  All India  2015-16         96.45           96.00     94.56       95.67

# %% [markdown]
# # Plot a graph to visualize boys toilet facilities in schools of India.

# %%
dg.groupby('year')['Primary_Only', 'U_Primary_Only','Sec_Only',  'HrSec_Only'].sum().plot(kind='bar',figsize = (15, 8), width=0.2)

plt.title('Percentage of boys toilet facilities in India schools',fontsize=15,pad='2.0')
plt.xlabel('Year') 
plt.ylabel('Percentage')
plt.legend(loc='lower right')
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# In 2013-14 school year, the facilities of boys toilets is really low for Higher Secondary Schools but they have a sudden growth from 2014-2015.
#
# Also in 2015-2016, Primary_Only,  U_Primary_Only, Sec_Only and  HrSec_Only  have an increase in boys toilet facilities.
#
# In 2015-2016, the  four schools have an increase in their boys toilet facilities as compared to 2014-2015.
#
# However, this sudden incease in 2015-2016 is realatively small amongst the schools .
#
# Hence Indian Govermnment should undertake initiatives  to ensure more increase in boys toilet facilities of all the schools.
