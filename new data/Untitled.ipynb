# %%
import pandas as pd
import numpy as np

# %%
df_enrol_2003_04=pd.read_excel("avg_enrol_03_04.xlsx").dropna(axis=1)
df_enrol_2004_05=pd.read_excel("avg_enrol_04_05.xlsx").dropna(axis=1)
df_enrol_2005_06=pd.read_excel("avg_enrol_05_06.xlsx").dropna(axis=1)
df_enrol_2006_07=pd.read_excel("avg_enrol_06-07.xlsx").dropna(axis=1)
df_enrol_2007_08=pd.read_excel("avg_enrol_07_08.xlsx").dropna(axis=1)
df_enrol_2008_09=pd.read_excel("avg_enrol_08_09.xlsx").dropna(axis=1)
df_enrol_2012_13=pd.read_excel("avg_enrol_12_13.xlsx").dropna(axis=1)
df_enrol_2013_14=pd.read_csv("avg_enrol_13_14.png.csv").dropna(axis=1)
df_enrol_2014_15=pd.read_csv("avg_enrol_14_15.png.csv").dropna(axis=1)
df_enrol_2015_16=pd.read_csv("avg_enrol_15_16.png.csv").dropna(axis=1)
df_enrol_2016_17=pd.read_csv("avg_Enrol16-17.png.csv").dropna(axis=1)
df_boys_toilet_2012_13=pd.read_excel("boys_toilet_12_13.xlsx").dropna(axis=1)
df_boys_toilet_2013_14=pd.read_excel("boys_toilet_13_14.xlsx").dropna(axis=1)
df_boys_toilet_2014_15=pd.read_csv("boys_toilet_14_15.csv").dropna(axis=1)
df_boys_toilet_2015_16=pd.read_csv("boys_toilet_15_16.png.csv").dropna(axis=1)
df_boys_toilet_2016_17=pd.read_csv("boys_toilet_16_17.png.csv").dropna(axis=1)
df_common_toilet_2003_04=pd.read_excel("common_toilet_03-04.xlsx").dropna(axis=1)
df_common_toilet_2004_05=pd.read_excel("common_toilet_04-05.xlsx").dropna(axis=1)
df_common_toilet_2005_06=pd.read_excel("common_toilet_05-06.xlsx").dropna(axis=1)
df_common_toilet_2006_07=pd.read_excel("common_toilet_06-07.xlsx").dropna(axis=1)
df_common_toilet_2007_08=pd.read_excel("common_toilet_07-08.xlsx").dropna(axis=1)
df_common_toilet_2008_09=pd.read_excel("common_toilet_08-09.xlsx").dropna(axis=1)
df_comp_2003_04=pd.read_excel("comp_03_04.xlsx").dropna(axis=1)
df_comp_2004_05=pd.read_excel("comp_04_05.xlsx").dropna(axis=1)
df_comp_2005_06=pd.read_excel("comp_05_06.xlsx").dropna(axis=1)
df_comp_2006_07=pd.read_excel("comp_06_07.xlsx").dropna(axis=1)
df_comp_2007_08=pd.read_excel("comp_07_08.xlsx").dropna(axis=1)
df_comp_2008_09=pd.read_excel("comp_08_09.xlsx").dropna(axis=1)
df_comp_2012_13=pd.read_excel("comp_12_13.xlsx").dropna(axis=1)
df_comp_2013_14=pd.read_csv("comp_13_14.png.csv").dropna(axis=1)
df_comp_2014_15=pd.read_csv("comp_14_15.png.csv").dropna(axis=1)
df_comp_2015_16=pd.read_csv("comp_15_16.png.csv").dropna(axis=1)
df_comp_2016_17=pd.read_csv("comp_16_17.png.csv").dropna(axis=1)
df_elec_2003_04=pd.read_excel("elec_03_04.xlsx").dropna(axis=1)
df_elec_2004_05=pd.read_excel("elec_04-05.xlsx").dropna(axis=1)
df_elec_2005_06=pd.read_excel("elec_05-06.xlsx").dropna(axis=1)
df_elec_2006_07=pd.read_excel("elec_06-07.xlsx").dropna(axis=1)
df_elec_2007_08=pd.read_excel("elec_07-08.xlsx").dropna(axis=1)
df_elec_2008_09=pd.read_excel("elec_08-09.xlsx").dropna(axis=1)
df_elec_2012_13=pd.read_excel("elec_12_13.xlsx").dropna(axis=1)
df_elec_2013_14=pd.read_csv("elec_13_14.png.csv").dropna(axis=1)
df_elec_2014_15=pd.read_csv("elec_14_15.png.csv").dropna(axis=1)
df_elec_2015_16=pd.read_csv("elec_15_16.png.csv").dropna(axis=1)
df_elec_2016_17=pd.read_csv("elec_16_17.png.csv").dropna(axis=1)
df_girls_toilet_2003_04=pd.read_excel("girls_toilet_03-04.xlsx").dropna(axis=1)
df_girls_toilet_2004_05=pd.read_excel("girls_toilet_04-05.xlsx").dropna(axis=1)
df_girls_toilet_2005_06=pd.read_excel("girls_toilet_05-06.xlsx").dropna(axis=1)
df_girls_toilet_2006_07=pd.read_excel("girls_toilet_06-07.xlsx").dropna(axis=1)
df_girls_toilet_2007_08=pd.read_excel("girls_toilet_07-08.xlsx").dropna(axis=1)
df_girls_toilet_2008_09=pd.read_excel("girls_toilet_08-09.xlsx").dropna(axis=1)
df_girls_toilet_2012_13=pd.read_excel("girls_toilet_12_13.xlsx").dropna(axis=1)
df_girls_toilet_2013_14=pd.read_excel("girls_toilet_13_14.xlsx").dropna(axis=1)
df_girls_toilet_2014_15=pd.read_csv("girls_toilet_14_15.png.csv").dropna(axis=1)
df_girls_toilet_2015_16=pd.read_csv("girls_toilet_15_16.png.csv").dropna(axis=1)
df_girls_toilet_2016_17=pd.read_csv("girls_toilet_16_17.png.csv").dropna(axis=1)
df_water_2003_04=pd.read_excel("water_03_04.xlsx").dropna(axis=1)
df_water_2004_05=pd.read_excel("water_04-05.xlsx").dropna(axis=1)
df_water_2005_06=pd.read_excel("water_05-06.xlsx").dropna(axis=1)
df_water_2006_07=pd.read_excel("water_06-07.xlsx").dropna(axis=1)
df_water_2007_08=pd.read_excel("water_07-08.xlsx").dropna(axis=1)
df_water_2008_09=pd.read_excel("water_08-09.xlsx").dropna(axis=1)
df_water_2012_13=pd.read_excel("water_12_13.xlsx").dropna(axis=1)
df_water_2013_14=pd.read_excel("water_13_14.xlsx").dropna(axis=1)
df_water_2014_15=pd.read_csv("water_14_15.png.csv").dropna(axis=1)
df_water_2015_16=pd.read_csv("water_15_16.png.csv").dropna(axis=1)
df_water_2016_17=pd.read_csv("water_16_17.png.csv").dropna(axis=1)

# %%
df_enrol_2003_04.name=f"{df_enrol_2003_04}"

# %%
years=["2003_04","2004_05","2005_06","2006_07","2007_08","2008_09","2012_13","2013_14","2014_15","2015_16","2016_17"]

# %%
ls=[]
ls.append(df_enrol_2003_04)

# %%
ls.append(df_enrol_2003_04)

# %%
def prep(lis):
    total = pd.Datafra
    for d in range(0,len(lis)):
        lis[d]["year"]=years[d]
        
    return lis

# %%
r=prep(ls)

# %%
years

# %%
for d in range(0,len(ls)):
    print(years[d])
# Out:
# 2003_04
# 2004_05
# 2005_06

# %%
ris=[df_enrol_2003_04,df_water_2015_16,df_water_2014_15]

# %%
df_comp_2013_14
# Out:
#              State/UT  Primary Only  Primary with Upper Primary  \
# 0       A & N Islands         30.40                       73.68
# 1      Andhra Pradesh         12.73                       42.72
# 2   Arunachal Pradesh          4.32                       45.05
# 3               Assam          1.08                       29.12
# 4               Bihar          1.42                        7.61
# 5          Chandigarh         54.55                       92.31
# 6        Chhattisgarh          2.65                       36.67
# 7        D & N Haveli          8.84                       66.94
# 8         Daman & Diu         14.55                       88.89
# 9               Delhi         80.55                       91.82
# 10                Goa         12.02                       89.66
# 11            Gujarat         24.74                       90.44
# 12            Haryana          7.43                       74.87
# 13   Himachal Pradesh          3.75                       82.75
# ...

# %%
r[1]
# Out:
#              State/UT  Primary Only  Primary with Upper Primary  \
# 0       A & N Islands        100.00                      100.00
# 1      Andhra Pradesh         93.07                       94.74
# 2   Arunachal Pradesh         71.88                       87.64
# 3               Assam         91.06                       97.07
# 4               Bihar         90.07                       99.09
# 5          Chandigarh        100.00                      100.00
# 6        Chhattisgarh         99.10                       99.44
# 7        D & N Haveli        100.00                      100.00
# 8         Daman & Diu        100.00                        0.00
# 9               Delhi        100.00                      100.00
# 10                Goa        100.00                      100.00
# 11            Gujarat         99.97                       99.92
# 12            Haryana         99.83                      100.00
# 13   Himachal Pradesh         99.88                      100.00
# ...
